# %% [markdown]
# # Tutorial 2 - The Queens & The Art of Branching

# %% [markdown]
# **Important:** You must fully complete Tutorial $i-1$ before starting Tutorial $i$ ($i>1$).
#
# Constraint programming is used to solve highly combinatorial and complex problems.
# In order to master CP, you need to get used to the philosophy behind this approach as well as the different
# techniques used along with it. We will guide you in this process step by step in the upcoming tutorials. We will be using "toy" puzzles/problems only for the purpose of learning different faces of CP. In real life problems, things get messed up easily and require decision and policy makes to agree opon the problem at hand.. (Trust us, we've been there..)
#
# In this tutorial, we use the N-Queens problem, one of oldest and classical problems solved efficiently by CP, as a case study.

# %% [markdown]
# ### Configurations

# %%
from config import setup
setup()
from docplex.cp.model import *

# %% [markdown]
# ## 1. The N-Queens problem

# %% [markdown]
# You are given an N-by-N chessboard, and your goal is to place N chess queens on it so that no two queens threaten each other:
#
# <div class="row" style="margin-top: 10px">
#     <div class="col-md-5">
#         <img src="display/images/empty-chessboard.png" style="margin-right: 0; width: 160px;" />
#     </div>
#     <div class="col-md-2" style="display: table">
#         <i class="fa fa-arrow-right" style="display: table-cell; font-size: 50px;
#         margin: auto; text-align: center; vertical-align: middle; height: 150px"></i>
#     </div>
#     <div class="col-md-5">
#         <img src="display/images/nqueens8-chessboard.png" style="margin-left: 0; width: 160px;" />
#     </div>
# </div>
#
# Formally, a solution to the N-queens problem requires that no two queens share the same row, column or diagnoal.

# %% [markdown]
# ### 1.1. Model without global constraints

# %% [markdown]
# **Exercice**: Create a function `decomposition_model(N)` that models the problem using only binary inequality constrants (no global constraint) and returns an instance of `CpoModel` for the n-queens problem with `N` queens.

# %%
def decomposition_model(N):
    
    ##Modele : 
    mdl = CpoModel(name='N_Queens')
    
    ##Variables : 
    x = mdl.integer_var_list(N, 1, N, 'col')
    
    ##Contraintes
    for i in range(0,N,1):
        for j in range(0,N,1):
            if i<j:
                mdl.add((j-i)!=abs(x[j]-x[i]))
            if (i!=j):
                mdl.add(x[i]!=x[j])
    return mdl

# %% [markdown]
# **Exercice:** Test your function by solving the n-queens problem for small values of $N$ ($N < 20$).
#
# <div class="alert alert-block alert-info">
#
# Use the `display.n_queens` function in order to display a solution for the n-queens problem. This function can take a list of `int` corresponding to the column of the queens in order to display them.
#
# </div>

# %%
import display

for N in range(5,20,1):
    mdl = decomposition_model(N)
    sol = mdl.solve()
    sol.print_solution()
    display.n_queens(sol.get_all_var_solutions())
# Out:
#  ! ----------------------------------------------------------------------------
#  ! Satisfiability problem - 5 variables, 30 constraints
#  ! Workers              = 1
#  ! Presolve             = Off
#  ! SearchType           = DepthFirst
#  ! Initial process time : 0.00s (0.00s extraction + 0.00s propagation)
#  !  . Log search space  : 11.6 (before), 11.6 (after)
#  !  . Memory usage      : 298.9 kB (before), 298.9 kB (after)
#  ! Using sequential search.
#  ! ----------------------------------------------------------------------------
#  !               Branches  Non-fixed            Branch decision
#  *                      5  0.00s                  4  = col_1
#  ! ----------------------------------------------------------------------------
#  ! Search completed, 1 solution found.
#  ! ----------------------------------------------------------------------------
#  ! Number of branches     : 5
#  ! Number of fails        : 1
#  ! Total memory usage     : 561.9 kB (522.1 kB CP Optimizer + 39.8 kB Concert)
#  ! Time spent in solve    : 0.00s (0.00s engine + 0.00s extraction)
#  ! Search speed (br. / s) : 500.0
#  ! ----------------------------------------------------------------------------
# -------------------------------------------------------------------------------
# Model constraints: 30, variables: integer: 5, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchCompleted, stop cause: SearchHasNotBeenStopped
# Solve time: 0 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 1
#    col_1 = 4
#    col_2 = 2
#    col_3 = 5
#    col_4 = 3
#  ! ----------------------------------------------------------------------------
#  ! Satisfiability problem - 6 variables, 45 constraints
#  ! Workers              = 1
#  ! Presolve             = Off
#  ! SearchType           = DepthFirst
#  ! Initial process time : 0.00s (0.00s extraction + 0.00s propagation)
#  !  . Log search space  : 15.5 (before), 15.5 (after)
#  !  . Memory usage      : 299.0 kB (before), 299.0 kB (after)
#  ! Using sequential search.
#  ! ----------------------------------------------------------------------------
#  !               Branches  Non-fixed            Branch decision
#  *                     32  0.00s                  1 != col_2
#  ! ----------------------------------------------------------------------------
#  ! Search completed, 1 solution found.
#  ! ----------------------------------------------------------------------------
#  ! Number of branches     : 32
#  ! Number of fails        : 14
#  ! Total memory usage     : 567.7 kB (527.8 kB CP Optimizer + 39.9 kB Concert)
#  ! Time spent in solve    : 0.00s (0.00s engine + 0.00s extraction)
#  ! Search speed (br. / s) : 3200.0
#  ! ----------------------------------------------------------------------------
# -------------------------------------------------------------------------------
# Model constraints: 45, variables: integer: 6, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchCompleted, stop cause: SearchHasNotBeenStopped
# Solve time: 0 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 2
#    col_1 = 4
#    col_2 = 6
#    col_3 = 1
#    col_4 = 3
#    col_5 = 5
#  ! ----------------------------------------------------------------------------
#  ! Satisfiability problem - 7 variables, 63 constraints
#  ! Workers              = 1
#  ! Presolve             = Off
#  ! SearchType           = DepthFirst
#  ! Initial process time : 0.00s (0.00s extraction + 0.00s propagation)
#  !  . Log search space  : 19.7 (before), 19.7 (after)
#  !  . Memory usage      : 299.0 kB (before), 299.0 kB (after)
#  ! Using sequential search.
#  ! ----------------------------------------------------------------------------
#  !               Branches  Non-fixed            Branch decision
#  *                     24  0.00s                  2 != col_4
#  ! ----------------------------------------------------------------------------
#  ! Search completed, 1 solution found.
#  ! ----------------------------------------------------------------------------
#  ! Number of branches     : 24
#  ! Number of fails        : 10
#  ! Total memory usage     : 584.8 kB (544.8 kB CP Optimizer + 40.0 kB Concert)
#  ! Time spent in solve    : 0.00s (0.00s engine + 0.00s extraction)
#  ! Search speed (br. / s) : 2400.0
#  ! ----------------------------------------------------------------------------
# -------------------------------------------------------------------------------
# Model constraints: 63, variables: integer: 7, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchCompleted, stop cause: SearchHasNotBeenStopped
# Solve time: 0 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 1
#    col_1 = 6
#    col_2 = 4
#    col_3 = 2
#    col_4 = 7
#    col_5 = 5
#    col_6 = 3
#  ! ----------------------------------------------------------------------------
#  ! Satisfiability problem - 8 variables, 84 constraints
#  ! Workers              = 1
#  ! Presolve             = Off
#  ! SearchType           = DepthFirst
#  ! Initial process time : 0.00s (0.00s extraction + 0.00s propagation)
#  !  . Log search space  : 24.0 (before), 24.0 (after)
#  !  . Memory usage      : 299.0 kB (before), 299.0 kB (after)
#  ! Using sequential search.
#  ! ----------------------------------------------------------------------------
#  !               Branches  Non-fixed            Branch decision
#  *                     61  0.00s                  2  = col_5
#  ! ----------------------------------------------------------------------------
#  ! Search completed, 1 solution found.
#  ! ----------------------------------------------------------------------------
#  ! Number of branches     : 61
#  ! Number of fails        : 28
#  ! Total memory usage     : 595.8 kB (555.8 kB CP Optimizer + 40.0 kB Concert)
#  ! Time spent in solve    : 0.00s (0.00s engine + 0.00s extraction)
#  ! Search speed (br. / s) : 6100.0
#  ! ----------------------------------------------------------------------------
# -------------------------------------------------------------------------------
# Model constraints: 84, variables: integer: 8, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchCompleted, stop cause: SearchHasNotBeenStopped
# Solve time: 0 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 1
#    col_1 = 7
#    col_2 = 4
#    col_3 = 6
#    col_4 = 8
#    col_5 = 2
#    col_6 = 5
#    col_7 = 3
#  ! ----------------------------------------------------------------------------
#  ! Satisfiability problem - 9 variables, 108 constraints
#  ! Workers              = 1
#  ! Presolve             = Off
#  ! SearchType           = DepthFirst
#  ! Initial process time : 0.00s (0.00s extraction + 0.00s propagation)
#  !  . Log search space  : 28.5 (before), 28.5 (after)
#  !  . Memory usage      : 299.1 kB (before), 299.1 kB (after)
#  ! Using sequential search.
#  ! ----------------------------------------------------------------------------
#  !               Branches  Non-fixed            Branch decision
#  *                    239  0.00s                  2  = col_4
#  ! ----------------------------------------------------------------------------
#  ! Search completed, 1 solution found.
#  ! ----------------------------------------------------------------------------
#  ! Number of branches     : 239
#  ! Number of fails        : 117
#  ! Total memory usage     : 613.3 kB (573.2 kB CP Optimizer + 40.1 kB Concert)
#  ! Time spent in solve    : 0.00s (0.00s engine + 0.00s extraction)
#  ! Search speed (br. / s) : 23900.0
#  ! ----------------------------------------------------------------------------
# -------------------------------------------------------------------------------
# Model constraints: 108, variables: integer: 9, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchCompleted, stop cause: SearchHasNotBeenStopped
# Solve time: 0 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 1
#    col_1 = 4
#    col_2 = 7
#    col_3 = 9
#    col_4 = 2
#    col_5 = 5
#    col_6 = 8
#    col_7 = 6
#    col_8 = 3
#  ! ----------------------------------------------------------------------------
#  ! Satisfiability problem - 10 variables, 135 constraints
#  ! Workers              = 1
#  ! Presolve             = Off
#  ! SearchType           = DepthFirst
#  ! Initial process time : 0.00s (0.00s extraction + 0.00s propagation)
#  !  . Log search space  : 33.2 (before), 33.2 (after)
#  !  . Memory usage      : 299.1 kB (before), 299.1 kB (after)
#  ! Using sequential search.
#  ! ----------------------------------------------------------------------------
#  !               Branches  Non-fixed            Branch decision
#  *                     52  0.00s                  5 != col_7
#  ! ----------------------------------------------------------------------------
#  ! Search completed, 1 solution found.
#  ! ----------------------------------------------------------------------------
#  ! Number of branches     : 52
#  ! Number of fails        : 23
#  ! Total memory usage     : 662.7 kB (622.5 kB CP Optimizer + 40.2 kB Concert)
#  ! Time spent in solve    : 0.00s (0.00s engine + 0.00s extraction)
#  ! Search speed (br. / s) : 5200.0
#  ! ----------------------------------------------------------------------------
# -------------------------------------------------------------------------------
# Model constraints: 135, variables: integer: 10, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchCompleted, stop cause: SearchHasNotBeenStopped
# Solve time: 0 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 7
#    col_1 = 3
#    col_2 = 1
#    col_3 = 8
#    col_4 = 5
#    col_5 = 9
#    col_6 = 6
#    col_7 = 10
#    col_8 = 2
#    col_9 = 4
#  ! ----------------------------------------------------------------------------
#  ! Satisfiability problem - 11 variables, 165 constraints
#  ! Workers              = 1
#  ! Presolve             = Off
#  ! SearchType           = DepthFirst
#  ! Initial process time : 0.00s (0.00s extraction + 0.00s propagation)
#  !  . Log search space  : 38.1 (before), 38.1 (after)
#  !  . Memory usage      : 299.2 kB (before), 299.2 kB (after)
#  ! Using sequential search.
#  ! ----------------------------------------------------------------------------
#  !               Branches  Non-fixed            Branch decision
#  *                     61  0.00s                  4  = col_8
#  ! ----------------------------------------------------------------------------
#  ! Search completed, 1 solution found.
#  ! ----------------------------------------------------------------------------
#  ! Number of branches     : 61
#  ! Number of fails        : 27
#  ! Total memory usage     : 692.4 kB (652.1 kB CP Optimizer + 40.3 kB Concert)
#  ! Time spent in solve    : 0.00s (0.00s engine + 0.00s extraction)
#  ! Search speed (br. / s) : 6100.0
#  ! ----------------------------------------------------------------------------
# -------------------------------------------------------------------------------
# Model constraints: 165, variables: integer: 11, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchCompleted, stop cause: SearchHasNotBeenStopped
# Solve time: 0 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 6
#    col_1 = 3
#    col_2 = 1
#    col_3 = 11
#    col_4 = 9
#    col_5 = 5
#    col_6 = 10
#    col_7 = 8
#    col_8 = 4
#    col_9 = 2
#    col_10 = 7
#  ! ----------------------------------------------------------------------------
#  ! Satisfiability problem - 12 variables, 198 constraints
#  ! Workers              = 1
#  ! Presolve             = Off
#  ! SearchType           = DepthFirst
#  ! Initial process time : 0.00s (0.00s extraction + 0.00s propagation)
#  !  . Log search space  : 43.0 (before), 43.0 (after)
#  !  . Memory usage      : 299.2 kB (before), 299.2 kB (after)
#  ! Using sequential search.
#  ! ----------------------------------------------------------------------------
#  !               Branches  Non-fixed            Branch decision
#  *                     76  0.00s                  7 != col_6
#  ! ----------------------------------------------------------------------------
#  ! Search completed, 1 solution found.
#  ! ----------------------------------------------------------------------------
#  ! Number of branches     : 76
#  ! Number of fails        : 35
#  ! Total memory usage     : 708.2 kB (667.8 kB CP Optimizer + 40.4 kB Concert)
#  ! Time spent in solve    : 0.00s (0.00s engine + 0.00s extraction)
#  ! Search speed (br. / s) : 7600.0
#  ! ----------------------------------------------------------------------------
# -------------------------------------------------------------------------------
# Model constraints: 198, variables: integer: 12, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchCompleted, stop cause: SearchHasNotBeenStopped
# Solve time: 0 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 5
#    col_1 = 3
#    col_2 = 1
#    col_3 = 7
#    col_4 = 11
#    col_5 = 6
#    col_6 = 12
#    col_7 = 10
#    col_8 = 8
#    col_9 = 4
#    col_10 = 2
#    col_11 = 9
#  ! ----------------------------------------------------------------------------
#  ! Satisfiability problem - 13 variables, 234 constraints
#  ! Workers              = 1
#  ! Presolve             = Off
#  ! SearchType           = DepthFirst
#  ! Initial process time : 0.00s (0.00s extraction + 0.00s propagation)
#  !  . Log search space  : 48.1 (before), 48.1 (after)
#  !  . Memory usage      : 339.5 kB (before), 339.5 kB (after)
#  ! Using sequential search.
#  ! ----------------------------------------------------------------------------
#  !               Branches  Non-fixed            Branch decision
#  *                    705  0.00s                  4 != col_6
#  ! ----------------------------------------------------------------------------
#  ! Search completed, 1 solution found.
#  ! ----------------------------------------------------------------------------
#  ! Number of branches     : 705
#  ! Number of fails        : 349
#  ! Total memory usage     : 767.1 kB (726.7 kB CP Optimizer + 40.4 kB Concert)
#  ! Time spent in solve    : 0.00s (0.00s engine + 0.00s extraction)
#  ! Search speed (br. / s) : 70500.0
#  ! ----------------------------------------------------------------------------
# -------------------------------------------------------------------------------
# Model constraints: 234, variables: integer: 13, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchCompleted, stop cause: SearchHasNotBeenStopped
# Solve time: 0 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 6
#    col_1 = 3
#    col_2 = 1
#    col_3 = 12
#    col_4 = 7
#    col_5 = 13
#    col_6 = 11
#    col_7 = 5
#    col_8 = 8
#    col_9 = 10
#    col_10 = 4
#    col_11 = 2
#    col_12 = 9
#  ! ----------------------------------------------------------------------------
#  ! Satisfiability problem - 14 variables, 273 constraints
#  ! Workers              = 1
#  ! Presolve             = Off
#  ! SearchType           = DepthFirst
#  ! Initial process time : 0.00s (0.00s extraction + 0.00s propagation)
#  !  . Log search space  : 53.3 (before), 53.3 (after)
#  !  . Memory usage      : 339.6 kB (before), 339.6 kB (after)
#  ! Using sequential search.
#  ! ----------------------------------------------------------------------------
#  !               Branches  Non-fixed            Branch decision
#  *                    382  0.00s                  5 != col_8
#  ! ----------------------------------------------------------------------------
#  ! Search completed, 1 solution found.
#  ! ----------------------------------------------------------------------------
#  ! Number of branches     : 382
#  ! Number of fails        : 185
#  ! Total memory usage     : 818.1 kB (777.6 kB CP Optimizer + 40.5 kB Concert)
#  ! Time spent in solve    : 0.00s (0.00s engine + 0.00s extraction)
#  ! Search speed (br. / s) : 38200.0
#  ! ----------------------------------------------------------------------------
# -------------------------------------------------------------------------------
# Model constraints: 273, variables: integer: 14, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchCompleted, stop cause: SearchHasNotBeenStopped
# Solve time: 0 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 11
#    col_1 = 8
#    col_2 = 3
#    col_3 = 1
#    col_4 = 4
#    col_5 = 7
#    col_6 = 10
#    col_7 = 12
#    col_8 = 14
#    col_9 = 5
#    col_10 = 13
#    col_11 = 6
#    col_12 = 9
#    col_13 = 2
#  ! ----------------------------------------------------------------------------
#  ! Satisfiability problem - 15 variables, 315 constraints
#  ! Workers              = 1
#  ! Presolve             = Off
#  ! SearchType           = DepthFirst
#  ! Initial process time : 0.00s (0.00s extraction + 0.00s propagation)
#  !  . Log search space  : 58.6 (before), 58.6 (after)
#  !  . Memory usage      : 339.6 kB (before), 339.6 kB (after)
#  ! Using sequential search.
#  ! ----------------------------------------------------------------------------
#  !               Branches  Non-fixed            Branch decision
#  *                    418  0.00s                 13  = col_0
#  ! ----------------------------------------------------------------------------
#  ! Search completed, 1 solution found.
#  ! ----------------------------------------------------------------------------
#  ! Number of branches     : 418
#  ! Number of fails        : 204
#  ! Total memory usage     : 878.2 kB (837.6 kB CP Optimizer + 40.6 kB Concert)
#  ! Time spent in solve    : 0.00s (0.00s engine + 0.00s extraction)
#  ! Search speed (br. / s) : 41800.0
#  ! ----------------------------------------------------------------------------
# -------------------------------------------------------------------------------
# Model constraints: 315, variables: integer: 15, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchCompleted, stop cause: SearchHasNotBeenStopped
# Solve time: 0 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 13
#    col_1 = 10
#    col_2 = 3
#    col_3 = 1
#    col_4 = 4
#    col_5 = 7
#    col_6 = 11
#    col_7 = 15
#    col_8 = 12
#    col_9 = 5
#    col_10 = 9
#    col_11 = 14
#    col_12 = 6
#    col_13 = 8
#    col_14 = 2
#  ! ----------------------------------------------------------------------------
#  ! Satisfiability problem - 16 variables, 360 constraints
#  ! Workers              = 1
#  ! Presolve             = Off
#  ! SearchType           = DepthFirst
#  ! Initial process time : 0.00s (0.00s extraction + 0.00s propagation)
#  !  . Log search space  : 64.0 (before), 64.0 (after)
#  !  . Memory usage      : 331.5 kB (before), 331.5 kB (after)
#  ! Using sequential search.
#  ! ----------------------------------------------------------------------------
#  !               Branches  Non-fixed            Branch decision
#                      1000          2        F    13  = col_8
#  *                   1355  0.00s                  5  = col_9
#  ! ----------------------------------------------------------------------------
#  ! Search completed, 1 solution found.
#  ! ----------------------------------------------------------------------------
#  ! Number of branches     : 1355
#  ! Number of fails        : 672
#  ! Total memory usage     : 921.6 kB (880.9 kB CP Optimizer + 40.7 kB Concert)
#  ! Time spent in solve    : 0.00s (0.00s engine + 0.00s extraction)
#  ! Search speed (br. / s) : 135500.0
#  ! ----------------------------------------------------------------------------
# -------------------------------------------------------------------------------
# Model constraints: 360, variables: integer: 16, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchCompleted, stop cause: SearchHasNotBeenStopped
# Solve time: 0.01 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 11
#    col_1 = 8
#    col_2 = 3
#    col_3 = 1
#    col_4 = 4
#    col_5 = 7
#    col_6 = 12
#    col_7 = 15
#    col_8 = 13
#    col_9 = 5
#    col_10 = 9
#    col_11 = 14
#    col_12 = 16
#    col_13 = 10
#    col_14 = 6
#    col_15 = 2
#  ! ----------------------------------------------------------------------------
#  ! Satisfiability problem - 17 variables, 408 constraints
#  ! Workers              = 1
#  ! Presolve             = Off
#  ! SearchType           = DepthFirst
#  ! Initial process time : 0.00s (0.00s extraction + 0.00s propagation)
#  !  . Log search space  : 69.5 (before), 69.5 (after)
#  !  . Memory usage      : 339.7 kB (before), 339.7 kB (after)
#  ! Using sequential search.
#  ! ----------------------------------------------------------------------------
#  !               Branches  Non-fixed            Branch decision
#  *                     33  0.00s                  6 != col_10
#  ! ----------------------------------------------------------------------------
#  ! Search completed, 1 solution found.
#  ! ----------------------------------------------------------------------------
#  ! Number of branches     : 33
#  ! Number of fails        : 11
#  ! Total memory usage     : 981.7 kB (941.0 kB CP Optimizer + 40.8 kB Concert)
#  ! Time spent in solve    : 0.00s (0.00s engine + 0.00s extraction)
#  ! Search speed (br. / s) : 3300.0
#  ! ----------------------------------------------------------------------------
# -------------------------------------------------------------------------------
# Model constraints: 408, variables: integer: 17, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchCompleted, stop cause: SearchHasNotBeenStopped
# Solve time: 0 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 15
#    col_1 = 13
#    col_2 = 3
#    col_3 = 1
#    col_4 = 4
#    col_5 = 7
#    col_6 = 10
#    col_7 = 17
#    col_8 = 11
#    col_9 = 14
#    col_10 = 16
#    col_11 = 6
#    col_12 = 9
#    col_13 = 12
#    col_14 = 8
#    col_15 = 5
#    col_16 = 2
#  ! ----------------------------------------------------------------------------
#  ! Satisfiability problem - 18 variables, 459 constraints
#  ! Workers              = 1
#  ! Presolve             = Off
#  ! SearchType           = DepthFirst
#  ! Initial process time : 0.01s (0.01s extraction + 0.00s propagation)
#  !  . Log search space  : 75.1 (before), 75.1 (after)
#  !  . Memory usage      : 371.8 kB (before), 371.8 kB (after)
#  ! Using sequential search.
#  ! ----------------------------------------------------------------------------
#  !               Branches  Non-fixed            Branch decision
#  *                     25  0.01s                  6  = col_12
#  ! ----------------------------------------------------------------------------
#  ! Search completed, 1 solution found.
#  ! ----------------------------------------------------------------------------
#  ! Number of branches     : 25
#  ! Number of fails        : 6
#  ! Total memory usage     : 1.0 MB (1.0 MB CP Optimizer + 0.0 MB Concert)
#  ! Time spent in solve    : 0.01s (0.00s engine + 0.01s extraction)
#  ! Search speed (br. / s) : 2500.0
#  ! ----------------------------------------------------------------------------
# -------------------------------------------------------------------------------
# Model constraints: 459, variables: integer: 18, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchCompleted, stop cause: SearchHasNotBeenStopped
# Solve time: 0.01 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 13
#    col_1 = 8
#    col_2 = 3
#    col_3 = 1
#    col_4 = 4
#    col_5 = 7
#    col_6 = 17
#    col_7 = 10
#    col_8 = 12
#    col_9 = 15
#    col_10 = 18
#    col_11 = 16
#    col_12 = 6
#    col_13 = 9
#    col_14 = 11
#    col_15 = 14
#    col_16 = 5
#    col_17 = 2
#  ! ----------------------------------------------------------------------------
#  ! Satisfiability problem - 19 variables, 513 constraints
#  ! Workers              = 1
#  ! Presolve             = Off
#  ! SearchType           = DepthFirst
#  ! Initial process time : 0.00s (0.00s extraction + 0.00s propagation)
#  !  . Log search space  : 80.7 (before), 80.7 (after)
#  !  . Memory usage      : 371.8 kB (before), 371.8 kB (after)
#  ! Using sequential search.
#  ! ----------------------------------------------------------------------------
#  !               Branches  Non-fixed            Branch decision
#  *                     50  0.00s                 13 != col_10
#  ! ----------------------------------------------------------------------------
#  ! Search completed, 1 solution found.
#  ! ----------------------------------------------------------------------------
#  ! Number of branches     : 50
#  ! Number of fails        : 20
#  ! Total memory usage     : 1.0 MB (1.0 MB CP Optimizer + 0.0 MB Concert)
#  ! Time spent in solve    : 0.00s (0.00s engine + 0.00s extraction)
#  ! Search speed (br. / s) : 5000.0
#  ! ----------------------------------------------------------------------------
# -------------------------------------------------------------------------------
# Model constraints: 513, variables: integer: 19, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchCompleted, stop cause: SearchHasNotBeenStopped
# Solve time: 0 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 8
#    col_1 = 6
#    col_2 = 16
#    col_3 = 3
#    col_4 = 1
#    col_5 = 4
#    col_6 = 13
#    col_7 = 18
#    col_8 = 9
#    col_9 = 12
#    col_10 = 19
#    col_11 = 5
#    col_12 = 14
#    col_13 = 17
#    col_14 = 10
#    col_15 = 7
#    col_16 = 11
#    col_17 = 15
#    col_18 = 2

# %% [markdown]
# **Question**: How many solutions are there for $N = 3,~\ldots,~10$?
#
# **Note:** To answer this question, you must force the solver to use a depth first strategy using  `CpoModel.start_search(SearchType="DepthFirst")`.

# %%
for N in range(3,10,1):
    mdl = decomposition_model(N)   
    sols=mdl.start_search(SearchType="DepthFirst")
    for sol in sols:
        sol.write()
# Out:
#  ! ----------------------------------------------------------------------------
#  ! Satisfiability problem - 3 variables, 9 constraints
#  ! Workers              = 1
#  ! Presolve             = Off
#  ! SearchType           = DepthFirst
#  ! Initial process time : 0.00s (0.00s extraction + 0.00s propagation)
#  !  . Log search space  : 4.8 (before), 4.8 (after)
#  !  . Memory usage      : 266.8 kB (before), 266.8 kB (after)
#  ! Using sequential search.
#  ! ----------------------------------------------------------------------------
#  !               Branches  Non-fixed            Branch decision
#  ! ----------------------------------------------------------------------------
#  ! Search completed, model has no solution.
#  ! ----------------------------------------------------------------------------
#  ! Number of branches     : 4
#  ! Number of fails        : 3
#  ! Total memory usage     : 540.4 kB (500.8 kB CP Optimizer + 39.6 kB Concert)
#  ! Time spent in solve    : 0.00s (0.00s engine + 0.00s extraction)
#  ! Search speed (br. / s) : 400.0
#  ! ----------------------------------------------------------------------------
#  ! ----------------------------------------------------------------------------
#  ! Satisfiability problem - 4 variables, 18 constraints
#  ! Workers              = 1
#  ! Presolve             = Off
#  ! SearchType           = DepthFirst
#  ! Initial process time : 0.00s (0.00s extraction + 0.00s propagation)
#  !  . Log search space  : 8.0 (before), 8.0 (after)
#  !  . Memory usage      : 298.9 kB (before), 298.9 kB (after)
#  ! Using sequential search.
#  ! ----------------------------------------------------------------------------
#  !               Branches  Non-fixed            Branch decision
#  *                      2  0.00s                  3  = col_0
# -------------------------------------------------------------------------------
# Model constraints: 18, variables: integer: 4, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 3
#    col_1 = 1
#    col_2 = 4
#    col_3 = 2
#  *                     18  0.00s                  1 != col_0
# -------------------------------------------------------------------------------
# Model constraints: 18, variables: integer: 4, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 2
#    col_1 = 4
#    col_2 = 1
#    col_3 = 3
#  ! ----------------------------------------------------------------------------
#  ! Search completed, 2 solutions found.
#  ! ----------------------------------------------------------------------------
#  ! Number of branches     : 18
#  ! Number of fails        : 8
#  ! Total memory usage     : 545.2 kB (505.5 kB CP Optimizer + 39.7 kB Concert)
#  ! Time spent in solve    : 0.00s (0.00s engine + 0.00s extraction)
#  ! Search speed (br. / s) : 1800.0
#  ! ----------------------------------------------------------------------------
#  ! ----------------------------------------------------------------------------
#  ! Satisfiability problem - 5 variables, 30 constraints
#  ! Workers              = 1
#  ! Presolve             = Off
#  ! SearchType           = DepthFirst
#  ! Initial process time : 0.00s (0.00s extraction + 0.00s propagation)
#  !  . Log search space  : 11.6 (before), 11.6 (after)
#  !  . Memory usage      : 298.9 kB (before), 298.9 kB (after)
#  ! Using sequential search.
#  ! ----------------------------------------------------------------------------
#  !               Branches  Non-fixed            Branch decision
#  *                      5  0.00s                  4  = col_1
# -------------------------------------------------------------------------------
# Model constraints: 30, variables: integer: 5, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 1
#    col_1 = 4
#    col_2 = 2
#    col_3 = 5
#    col_4 = 3
#  *                      7  0.01s                  3 != col_4
# -------------------------------------------------------------------------------
# Model constraints: 30, variables: integer: 5, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0.01 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 1
#    col_1 = 3
#    col_2 = 5
#    col_3 = 2
#    col_4 = 4
#  *                     12  0.01s                  4 != col_1
# -------------------------------------------------------------------------------
# Model constraints: 30, variables: integer: 5, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0.01 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 2
#    col_1 = 5
#    col_2 = 3
#    col_3 = 1
#    col_4 = 4
#  *                     14  0.01s                  3  = col_3
# -------------------------------------------------------------------------------
# Model constraints: 30, variables: integer: 5, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0.01 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 2
#    col_1 = 4
#    col_2 = 1
#    col_3 = 3
#    col_4 = 5
#  *                     22  0.01s                  1 != col_1
# -------------------------------------------------------------------------------
# Model constraints: 30, variables: integer: 5, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0.01 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 3
#    col_1 = 5
#    col_2 = 2
#    col_3 = 4
#    col_4 = 1
#  *                     24  0.01s                  1  = col_1
# -------------------------------------------------------------------------------
# Model constraints: 30, variables: integer: 5, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0.01 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 3
#    col_1 = 1
#    col_2 = 4
#    col_3 = 2
#    col_4 = 5
#  *                     34  0.01s                  3  = col_3
# -------------------------------------------------------------------------------
# Model constraints: 30, variables: integer: 5, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0.01 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 4
#    col_1 = 2
#    col_2 = 5
#    col_3 = 3
#    col_4 = 1
#  *                     36  0.01s                  1  = col_1
# -------------------------------------------------------------------------------
# Model constraints: 30, variables: integer: 5, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0.01 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 4
#    col_1 = 1
#    col_2 = 3
#    col_3 = 5
#    col_4 = 2
#  *                     42  0.01s                  3  = col_4
# -------------------------------------------------------------------------------
# Model constraints: 30, variables: integer: 5, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0.01 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 5
#    col_1 = 2
#    col_2 = 4
#    col_3 = 1
#    col_4 = 3
#  *                     44  0.01s                  2 != col_1
# -------------------------------------------------------------------------------
# Model constraints: 30, variables: integer: 5, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0.01 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 5
#    col_1 = 3
#    col_2 = 1
#    col_3 = 4
#    col_4 = 2
#  ! ----------------------------------------------------------------------------
#  ! Search completed, 10 solutions found.
#  ! ----------------------------------------------------------------------------
#  ! Number of branches     : 44
#  ! Number of fails        : 13
#  ! Total memory usage     : 562.2 kB (522.4 kB CP Optimizer + 39.8 kB Concert)
#  ! Time spent in solve    : 0.01s (0.01s engine + 0.00s extraction)
#  ! Search speed (br. / s) : 4400.0
#  ! ----------------------------------------------------------------------------
#  ! ----------------------------------------------------------------------------
#  ! Satisfiability problem - 6 variables, 45 constraints
#  ! Workers              = 1
#  ! Presolve             = Off
#  ! SearchType           = DepthFirst
#  ! Initial process time : 0.00s (0.00s extraction + 0.00s propagation)
#  !  . Log search space  : 15.5 (before), 15.5 (after)
#  !  . Memory usage      : 299.0 kB (before), 299.0 kB (after)
#  ! Using sequential search.
#  ! ----------------------------------------------------------------------------
#  !               Branches  Non-fixed            Branch decision
#  *                     32  0.00s                  1 != col_2
# -------------------------------------------------------------------------------
# Model constraints: 45, variables: integer: 6, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 2
#    col_1 = 4
#    col_2 = 6
#    col_3 = 1
#    col_4 = 3
#    col_5 = 5
#  *                     69  0.00s                  2 != col_1
# -------------------------------------------------------------------------------
# Model constraints: 45, variables: integer: 6, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 3
#    col_1 = 6
#    col_2 = 2
#    col_3 = 5
#    col_4 = 1
#    col_5 = 4
#  *                     85  0.00s                  1 != col_4
# -------------------------------------------------------------------------------
# Model constraints: 45, variables: integer: 6, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 4
#    col_1 = 1
#    col_2 = 5
#    col_3 = 2
#    col_4 = 6
#    col_5 = 3
#  *                    125  0.00s                  1 != col_3
# -------------------------------------------------------------------------------
# Model constraints: 45, variables: integer: 6, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 5
#    col_1 = 3
#    col_2 = 1
#    col_3 = 6
#    col_4 = 4
#    col_5 = 2
#  ! ----------------------------------------------------------------------------
#  ! Search completed, 4 solutions found.
#  ! ----------------------------------------------------------------------------
#  ! Number of branches     : 146
#  ! Number of fails        : 70
#  ! Total memory usage     : 568.0 kB (528.1 kB CP Optimizer + 39.9 kB Concert)
#  ! Time spent in solve    : 0.00s (0.00s engine + 0.00s extraction)
#  ! Search speed (br. / s) : 14600.0
#  ! ----------------------------------------------------------------------------
#  ! ----------------------------------------------------------------------------
#  ! Satisfiability problem - 7 variables, 63 constraints
#  ! Workers              = 1
#  ! Presolve             = Off
#  ! SearchType           = DepthFirst
#  ! Initial process time : 0.00s (0.00s extraction + 0.00s propagation)
#  !  . Log search space  : 19.7 (before), 19.7 (after)
#  !  . Memory usage      : 299.0 kB (before), 299.0 kB (after)
#  ! Using sequential search.
#  ! ----------------------------------------------------------------------------
#  !               Branches  Non-fixed            Branch decision
#  *                     24  0.00s                  2 != col_4
# -------------------------------------------------------------------------------
# Model constraints: 63, variables: integer: 7, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 1
#    col_1 = 6
#    col_2 = 4
#    col_3 = 2
#    col_4 = 7
#    col_5 = 5
#    col_6 = 3
#  *                     38  0.00s                  2 != col_5
# -------------------------------------------------------------------------------
# Model constraints: 63, variables: integer: 7, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 1
#    col_1 = 5
#    col_2 = 2
#    col_3 = 6
#    col_4 = 3
#    col_5 = 7
#    col_6 = 4
#  *                     53  0.00s                  2  = col_5
# -------------------------------------------------------------------------------
# Model constraints: 63, variables: integer: 7, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 1
#    col_1 = 4
#    col_2 = 7
#    col_3 = 3
#    col_4 = 6
#    col_5 = 2
#    col_6 = 5
#  *                     74  0.00s                  2 != col_3
# -------------------------------------------------------------------------------
# Model constraints: 63, variables: integer: 7, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 1
#    col_1 = 3
#    col_2 = 5
#    col_3 = 7
#    col_4 = 2
#    col_5 = 4
#    col_6 = 6
#  *                     89  0.00s                  4  = col_4
# -------------------------------------------------------------------------------
# Model constraints: 63, variables: integer: 7, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 2
#    col_1 = 6
#    col_2 = 3
#    col_3 = 7
#    col_4 = 4
#    col_5 = 1
#    col_6 = 5
#  *                     98  0.00s                  1  = col_2
# -------------------------------------------------------------------------------
# Model constraints: 63, variables: integer: 7, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 2
#    col_1 = 4
#    col_2 = 1
#    col_3 = 7
#    col_4 = 5
#    col_5 = 3
#    col_6 = 6
#  *                    102  0.00s                  1  = col_4
# -------------------------------------------------------------------------------
# Model constraints: 63, variables: integer: 7, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 2
#    col_1 = 5
#    col_2 = 7
#    col_3 = 4
#    col_4 = 1
#    col_5 = 3
#    col_6 = 6
#  *                    103  0.00s                  1 != col_4
# -------------------------------------------------------------------------------
# Model constraints: 63, variables: integer: 7, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 2
#    col_1 = 5
#    col_2 = 1
#    col_3 = 4
#    col_4 = 7
#    col_5 = 3
#    col_6 = 6
#  *                    113  0.00s                  1  = col_3
# -------------------------------------------------------------------------------
# Model constraints: 63, variables: integer: 7, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 2
#    col_1 = 5
#    col_2 = 3
#    col_3 = 1
#    col_4 = 7
#    col_5 = 4
#    col_6 = 6
#  *                    132  0.00s                  1  = col_3
# -------------------------------------------------------------------------------
# Model constraints: 63, variables: integer: 7, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 2
#    col_1 = 4
#    col_2 = 6
#    col_3 = 1
#    col_4 = 3
#    col_5 = 5
#    col_6 = 7
#  *                    156  0.00s                  1  = col_4
# -------------------------------------------------------------------------------
# Model constraints: 63, variables: integer: 7, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 2
#    col_1 = 7
#    col_2 = 5
#    col_3 = 3
#    col_4 = 1
#    col_5 = 6
#    col_6 = 4
#  *                    167  0.00s                  2  = col_2
# -------------------------------------------------------------------------------
# Model constraints: 63, variables: integer: 7, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 3
#    col_1 = 6
#    col_2 = 2
#    col_3 = 5
#    col_4 = 1
#    col_5 = 4
#    col_6 = 7
#  *                    200  0.00s                  1 != col_3
# -------------------------------------------------------------------------------
# Model constraints: 63, variables: integer: 7, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 3
#    col_1 = 1
#    col_2 = 6
#    col_3 = 4
#    col_4 = 2
#    col_5 = 7
#    col_6 = 5
#  *                    212  0.00s                  2  = col_3
# -------------------------------------------------------------------------------
# Model constraints: 63, variables: integer: 7, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 3
#    col_1 = 5
#    col_2 = 7
#    col_3 = 2
#    col_4 = 4
#    col_5 = 6
#    col_6 = 1
#  *                    236  0.00s                  1  = col_1
# -------------------------------------------------------------------------------
# Model constraints: 63, variables: integer: 7, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 3
#    col_1 = 1
#    col_2 = 6
#    col_3 = 2
#    col_4 = 5
#    col_5 = 7
#    col_6 = 4
#  *                    242  0.00s                  4 != col_6
# -------------------------------------------------------------------------------
# Model constraints: 63, variables: integer: 7, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 3
#    col_1 = 7
#    col_2 = 4
#    col_3 = 1
#    col_4 = 5
#    col_5 = 2
#    col_6 = 6
#  *                    257  0.00s                  1 != col_1
# -------------------------------------------------------------------------------
# Model constraints: 63, variables: integer: 7, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 3
#    col_1 = 7
#    col_2 = 2
#    col_3 = 4
#    col_4 = 6
#    col_5 = 1
#    col_6 = 5
#  *                    264  0.00s                  5  = col_2
# -------------------------------------------------------------------------------
# Model constraints: 63, variables: integer: 7, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 4
#    col_1 = 7
#    col_2 = 5
#    col_3 = 2
#    col_4 = 6
#    col_5 = 1
#    col_6 = 3
#  *                    268  0.00s                  1  = col_1
# -------------------------------------------------------------------------------
# Model constraints: 63, variables: integer: 7, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 4
#    col_1 = 1
#    col_2 = 5
#    col_3 = 2
#    col_4 = 6
#    col_5 = 3
#    col_6 = 7
#  *                    307  0.00s                  1 != col_6
#  ! Time = 0.00s, Average fail depth = 4, Memory usage = 544.4 kB
#  !               Branches  Non-fixed            Branch decision
# -------------------------------------------------------------------------------
# Model constraints: 63, variables: integer: 7, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 4
#    col_1 = 6
#    col_2 = 1
#    col_3 = 3
#    col_4 = 5
#    col_5 = 7
#    col_6 = 2
#  *                    325  0.00s                  3  = col_4
# -------------------------------------------------------------------------------
# Model constraints: 63, variables: integer: 7, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 4
#    col_1 = 2
#    col_2 = 7
#    col_3 = 5
#    col_4 = 3
#    col_5 = 1
#    col_6 = 6
#  *                    360  0.00s                  3 != col_1
# -------------------------------------------------------------------------------
# Model constraints: 63, variables: integer: 7, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 4
#    col_1 = 7
#    col_2 = 3
#    col_3 = 6
#    col_4 = 2
#    col_5 = 5
#    col_6 = 1
#  *                    364  0.00s                  2  = col_4
# -------------------------------------------------------------------------------
# Model constraints: 63, variables: integer: 7, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 4
#    col_1 = 1
#    col_2 = 3
#    col_3 = 6
#    col_4 = 2
#    col_5 = 7
#    col_6 = 5
#  *                    388  0.00s                  1 != col_2
# -------------------------------------------------------------------------------
# Model constraints: 63, variables: integer: 7, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 5
#    col_1 = 1
#    col_2 = 6
#    col_3 = 4
#    col_4 = 2
#    col_5 = 7
#    col_6 = 3
#  *                    398  0.00s                  1 != col_1
# -------------------------------------------------------------------------------
# Model constraints: 63, variables: integer: 7, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 5
#    col_1 = 7
#    col_2 = 2
#    col_3 = 6
#    col_4 = 3
#    col_5 = 1
#    col_6 = 4
#  *                    404  0.00s                  1  = col_1
# -------------------------------------------------------------------------------
# Model constraints: 63, variables: integer: 7, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 5
#    col_1 = 1
#    col_2 = 4
#    col_3 = 7
#    col_4 = 3
#    col_5 = 6
#    col_6 = 2
#  *                    426  0.00s                  1 != col_3
# -------------------------------------------------------------------------------
# Model constraints: 63, variables: integer: 7, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 5
#    col_1 = 3
#    col_2 = 1
#    col_3 = 6
#    col_4 = 4
#    col_5 = 2
#    col_6 = 7
#  *                    448  0.00s                  1 != col_3
# -------------------------------------------------------------------------------
# Model constraints: 63, variables: integer: 7, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 5
#    col_1 = 7
#    col_2 = 2
#    col_3 = 4
#    col_4 = 6
#    col_5 = 1
#    col_6 = 3
#  *                    463  0.00s                  2 != col_2
# -------------------------------------------------------------------------------
# Model constraints: 63, variables: integer: 7, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 5
#    col_1 = 2
#    col_2 = 6
#    col_3 = 3
#    col_4 = 7
#    col_5 = 4
#    col_6 = 1
#  *                    475  0.00s                  4 != col_4
# -------------------------------------------------------------------------------
# Model constraints: 63, variables: integer: 7, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 6
#    col_1 = 1
#    col_2 = 3
#    col_3 = 5
#    col_4 = 7
#    col_5 = 2
#    col_6 = 4
#  *                    492  0.00s                  1  = col_6
# -------------------------------------------------------------------------------
# Model constraints: 63, variables: integer: 7, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 6
#    col_1 = 4
#    col_2 = 2
#    col_3 = 7
#    col_4 = 5
#    col_5 = 3
#    col_6 = 1
#  *                    511  0.00s                  1 != col_3
# -------------------------------------------------------------------------------
# Model constraints: 63, variables: integer: 7, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 6
#    col_1 = 3
#    col_2 = 5
#    col_3 = 7
#    col_4 = 1
#    col_5 = 4
#    col_6 = 2
#  *                    522  0.00s                  1  = col_2
# -------------------------------------------------------------------------------
# Model constraints: 63, variables: integer: 7, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 6
#    col_1 = 3
#    col_2 = 1
#    col_3 = 4
#    col_4 = 7
#    col_5 = 5
#    col_6 = 2
#  *                    523  0.00s                  1 != col_2
# -------------------------------------------------------------------------------
# Model constraints: 63, variables: integer: 7, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 6
#    col_1 = 3
#    col_2 = 7
#    col_3 = 4
#    col_4 = 1
#    col_5 = 5
#    col_6 = 2
#  *                    529  0.00s                  1  = col_3
# -------------------------------------------------------------------------------
# Model constraints: 63, variables: integer: 7, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 6
#    col_1 = 4
#    col_2 = 7
#    col_3 = 1
#    col_4 = 3
#    col_5 = 5
#    col_6 = 2
#  *                    538  0.00s                  2  = col_1
# -------------------------------------------------------------------------------
# Model constraints: 63, variables: integer: 7, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 6
#    col_1 = 2
#    col_2 = 5
#    col_3 = 1
#    col_4 = 4
#    col_5 = 7
#    col_6 = 3
#  *                    563  0.00s                  1 != col_3
# -------------------------------------------------------------------------------
# Model constraints: 63, variables: integer: 7, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 7
#    col_1 = 2
#    col_2 = 4
#    col_3 = 6
#    col_4 = 1
#    col_5 = 3
#    col_6 = 5
#  *                    576  0.00s                  1  = col_5
# -------------------------------------------------------------------------------
# Model constraints: 63, variables: integer: 7, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0.01 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 7
#    col_1 = 3
#    col_2 = 6
#    col_3 = 2
#    col_4 = 5
#    col_5 = 1
#    col_6 = 4
#  *                    591  0.00s                  1 != col_5
# -------------------------------------------------------------------------------
# Model constraints: 63, variables: integer: 7, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0.01 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 7
#    col_1 = 4
#    col_2 = 1
#    col_3 = 5
#    col_4 = 2
#    col_5 = 6
#    col_6 = 3
#  *                    614  0.00s                  1  = col_3
#  ! Time = 0.00s, Average fail depth = 4, Memory usage = 544.4 kB
#  !               Branches  Non-fixed            Branch decision
# -------------------------------------------------------------------------------
# Model constraints: 63, variables: integer: 7, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0.01 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 7
#    col_1 = 5
#    col_2 = 3
#    col_3 = 1
#    col_4 = 6
#    col_5 = 4
#    col_6 = 2
#  ! ----------------------------------------------------------------------------
#  ! Search completed, 40 solutions found.
#  ! ----------------------------------------------------------------------------
#  ! Number of branches     : 620
#  ! Number of fails        : 271
#  ! Total memory usage     : 585.1 kB (545.2 kB CP Optimizer + 40.0 kB Concert)
#  ! Time spent in solve    : 0.00s (0.00s engine + 0.00s extraction)
#  ! Search speed (br. / s) : 62000.0
#  ! ----------------------------------------------------------------------------
#  ! ----------------------------------------------------------------------------
#  ! Satisfiability problem - 8 variables, 84 constraints
#  ! Workers              = 1
#  ! Presolve             = Off
#  ! SearchType           = DepthFirst
#  ! Initial process time : 0.00s (0.00s extraction + 0.00s propagation)
#  !  . Log search space  : 24.0 (before), 24.0 (after)
#  !  . Memory usage      : 299.0 kB (before), 299.0 kB (after)
#  ! Using sequential search.
#  ! ----------------------------------------------------------------------------
#  !               Branches  Non-fixed            Branch decision
#  *                     61  0.00s                  2  = col_5
# -------------------------------------------------------------------------------
# Model constraints: 84, variables: integer: 8, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 1
#    col_1 = 7
#    col_2 = 4
#    col_3 = 6
#    col_4 = 8
#    col_5 = 2
#    col_6 = 5
#    col_7 = 3
#  *                     69  0.00s                  2  = col_4
# -------------------------------------------------------------------------------
# Model constraints: 84, variables: integer: 8, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 1
#    col_1 = 7
#    col_2 = 5
#    col_3 = 8
#    col_4 = 2
#    col_5 = 4
#    col_6 = 6
#    col_7 = 3
#  *                    112  0.00s                  2 != col_2
# -------------------------------------------------------------------------------
# Model constraints: 84, variables: integer: 8, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 1
#    col_1 = 5
#    col_2 = 8
#    col_3 = 6
#    col_4 = 3
#    col_5 = 7
#    col_6 = 2
#    col_7 = 4
#  *                    174  0.00s                  2  = col_6
# -------------------------------------------------------------------------------
# Model constraints: 84, variables: integer: 8, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 1
#    col_1 = 6
#    col_2 = 8
#    col_3 = 3
#    col_4 = 7
#    col_5 = 4
#    col_6 = 2
#    col_7 = 5
#  *                    297  0.00s                  5 != col_4
# -------------------------------------------------------------------------------
# Model constraints: 84, variables: integer: 8, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 2
#    col_1 = 7
#    col_2 = 3
#    col_3 = 6
#    col_4 = 8
#    col_5 = 5
#    col_6 = 1
#    col_7 = 4
#  *                    328  0.00s                  1  = col_2
# -------------------------------------------------------------------------------
# Model constraints: 84, variables: integer: 8, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 2
#    col_1 = 6
#    col_2 = 1
#    col_3 = 7
#    col_4 = 4
#    col_5 = 8
#    col_6 = 3
#    col_7 = 5
#  *                    510  0.00s                  1  = col_4
# -------------------------------------------------------------------------------
# Model constraints: 84, variables: integer: 8, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 2
#    col_1 = 5
#    col_2 = 7
#    col_3 = 4
#    col_4 = 1
#    col_5 = 8
#    col_6 = 6
#    col_7 = 3
#  *                    515  0.00s                  1  = col_3
# -------------------------------------------------------------------------------
# Model constraints: 84, variables: integer: 8, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 2
#    col_1 = 5
#    col_2 = 7
#    col_3 = 1
#    col_4 = 3
#    col_5 = 8
#    col_6 = 6
#    col_7 = 4
#  *                    526  0.00s                  4 != col_3
# -------------------------------------------------------------------------------
# Model constraints: 84, variables: integer: 8, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 2
#    col_1 = 7
#    col_2 = 5
#    col_3 = 8
#    col_4 = 1
#    col_5 = 4
#    col_6 = 6
#    col_7 = 3
#  *                    587  0.00s                  5  = col_5
# -------------------------------------------------------------------------------
# Model constraints: 84, variables: integer: 8, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 2
#    col_1 = 8
#    col_2 = 6
#    col_3 = 1
#    col_4 = 3
#    col_5 = 5
#    col_6 = 7
#    col_7 = 4
#  *                    602  0.00s                  1  = col_5
# -------------------------------------------------------------------------------
# Model constraints: 84, variables: integer: 8, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 2
#    col_1 = 4
#    col_2 = 6
#    col_3 = 8
#    col_4 = 3
#    col_5 = 1
#    col_6 = 7
#    col_7 = 5
#  *                    606  0.00s                  1  = col_4
# -------------------------------------------------------------------------------
# Model constraints: 84, variables: integer: 8, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 2
#    col_1 = 6
#    col_2 = 8
#    col_3 = 3
#    col_4 = 1
#    col_5 = 4
#    col_6 = 7
#    col_7 = 5
#  *                    618  0.00s                  6 != col_1
# -------------------------------------------------------------------------------
# Model constraints: 84, variables: integer: 8, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 3
#    col_1 = 7
#    col_2 = 2
#    col_3 = 8
#    col_4 = 5
#    col_5 = 1
#    col_6 = 4
#    col_7 = 6
#  *                    654  0.00s                  2 != col_2
# -------------------------------------------------------------------------------
# Model constraints: 84, variables: integer: 8, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 3
#    col_1 = 6
#    col_2 = 8
#    col_3 = 2
#    col_4 = 4
#    col_5 = 1
#    col_6 = 7
#    col_7 = 5
#  *                    656  0.00s                  4 != col_4
# -------------------------------------------------------------------------------
# Model constraints: 84, variables: integer: 8, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 3
#    col_1 = 6
#    col_2 = 2
#    col_3 = 5
#    col_4 = 8
#    col_5 = 1
#    col_6 = 7
#    col_7 = 4
#  *                    670  0.00s                  2  = col_2
# -------------------------------------------------------------------------------
# Model constraints: 84, variables: integer: 8, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 3
#    col_1 = 6
#    col_2 = 2
#    col_3 = 7
#    col_4 = 5
#    col_5 = 1
#    col_6 = 8
#    col_7 = 4
#  *                    691  0.00s                  1 != col_4
# -------------------------------------------------------------------------------
# Model constraints: 84, variables: integer: 8, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 3
#    col_1 = 1
#    col_2 = 7
#    col_3 = 5
#    col_4 = 8
#    col_5 = 2
#    col_6 = 4
#    col_7 = 6
#  *                    729  0.00s                  4  = col_4
# -------------------------------------------------------------------------------
# Model constraints: 84, variables: integer: 8, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 3
#    col_1 = 5
#    col_2 = 7
#    col_3 = 1
#    col_4 = 4
#    col_5 = 2
#    col_6 = 8
#    col_7 = 6
#  *                    753  0.00s                  2 != col_3
# -------------------------------------------------------------------------------
# Model constraints: 84, variables: integer: 8, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 3
#    col_1 = 5
#    col_2 = 2
#    col_3 = 8
#    col_4 = 6
#    col_5 = 4
#    col_6 = 7
#    col_7 = 1
#  *                    773  0.00s                  1 != col_7
#  ! Time = 0.00s, Average fail depth = 5, Memory usage = 555.4 kB
#  !               Branches  Non-fixed            Branch decision
# -------------------------------------------------------------------------------
# Model constraints: 84, variables: integer: 8, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 3
#    col_1 = 6
#    col_2 = 2
#    col_3 = 7
#    col_4 = 1
#    col_5 = 4
#    col_6 = 8
#    col_7 = 5
#  *                    779  0.00s                  2 != col_3
# -------------------------------------------------------------------------------
# Model constraints: 84, variables: integer: 8, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 3
#    col_1 = 7
#    col_2 = 2
#    col_3 = 8
#    col_4 = 6
#    col_5 = 4
#    col_6 = 1
#    col_7 = 5
#  *                    793  0.00s                  1  = col_3
# -------------------------------------------------------------------------------
# Model constraints: 84, variables: integer: 8, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 3
#    col_1 = 6
#    col_2 = 4
#    col_3 = 1
#    col_4 = 8
#    col_5 = 5
#    col_6 = 7
#    col_7 = 2
#  *                    799  0.00s                  1 != col_4
# -------------------------------------------------------------------------------
# Model constraints: 84, variables: integer: 8, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 3
#    col_1 = 6
#    col_2 = 4
#    col_3 = 2
#    col_4 = 8
#    col_5 = 5
#    col_6 = 7
#    col_7 = 1
#  *                    874  0.00s                  1 != col_1
# -------------------------------------------------------------------------------
# Model constraints: 84, variables: integer: 8, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 3
#    col_1 = 8
#    col_2 = 4
#    col_3 = 7
#    col_4 = 1
#    col_5 = 6
#    col_6 = 2
#    col_7 = 5
#  *                    897  0.00s                  4 != col_3
# -------------------------------------------------------------------------------
# Model constraints: 84, variables: integer: 8, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 3
#    col_1 = 5
#    col_2 = 2
#    col_3 = 8
#    col_4 = 1
#    col_5 = 7
#    col_6 = 4
#    col_7 = 6
#  *                    926  0.00s                  2  = col_7
# -------------------------------------------------------------------------------
# Model constraints: 84, variables: integer: 8, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 3
#    col_1 = 6
#    col_2 = 8
#    col_3 = 1
#    col_4 = 4
#    col_5 = 7
#    col_6 = 5
#    col_7 = 2
#  *                    928  0.00s                  4 != col_4
# -------------------------------------------------------------------------------
# Model constraints: 84, variables: integer: 8, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0 sec
# ...
# Solve time: 0.08 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 8
#    col_1 = 5
#    col_2 = 3
#    col_3 = 1
#    col_4 = 7
#    col_5 = 4
#    col_6 = 6
#    col_7 = 9
#    col_8 = 2
#  *                  10520  0.08s                  1 != col_3
# -------------------------------------------------------------------------------
# Model constraints: 108, variables: integer: 9, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0.08 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 9
#    col_1 = 5
#    col_2 = 3
#    col_3 = 8
#    col_4 = 4
#    col_5 = 7
#    col_6 = 1
#    col_7 = 6
#    col_8 = 2
#  *                  10622  0.08s                  1 != col_6
# -------------------------------------------------------------------------------
# Model constraints: 108, variables: integer: 9, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0.08 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 9
#    col_1 = 4
#    col_2 = 6
#    col_3 = 8
#    col_4 = 3
#    col_5 = 1
#    col_6 = 7
#    col_7 = 5
#    col_8 = 2
#  *                  10630  0.08s                  1  = col_4
# -------------------------------------------------------------------------------
# Model constraints: 108, variables: integer: 9, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0.08 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 9
#    col_1 = 3
#    col_2 = 6
#    col_3 = 4
#    col_4 = 1
#    col_5 = 8
#    col_6 = 5
#    col_7 = 7
#    col_8 = 2
#  *                  10687  0.08s                  5 != col_2
# -------------------------------------------------------------------------------
# Model constraints: 108, variables: integer: 9, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0.08 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 9
#    col_1 = 6
#    col_2 = 8
#    col_3 = 2
#    col_4 = 4
#    col_5 = 1
#    col_6 = 7
#    col_7 = 5
#    col_8 = 3
#  *                  10693  0.08s                  1 != col_4
# -------------------------------------------------------------------------------
# Model constraints: 108, variables: integer: 9, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0.08 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 9
#    col_1 = 6
#    col_2 = 4
#    col_3 = 2
#    col_4 = 8
#    col_5 = 5
#    col_6 = 7
#    col_7 = 1
#    col_8 = 3
#  *                  10728  0.08s                  2 != col_2
#  ! Time = 0.08s, Average fail depth = 6, Memory usage = 605.2 kB
#  !               Branches  Non-fixed            Branch decision
# -------------------------------------------------------------------------------
# Model constraints: 108, variables: integer: 9, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0.08 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 9
#    col_1 = 5
#    col_2 = 8
#    col_3 = 4
#    col_4 = 1
#    col_5 = 7
#    col_6 = 2
#    col_7 = 6
#    col_8 = 3
#  *                  10730  0.08s                  2  = col_6
# -------------------------------------------------------------------------------
# Model constraints: 108, variables: integer: 9, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0.08 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 9
#    col_1 = 5
#    col_2 = 1
#    col_3 = 4
#    col_4 = 6
#    col_5 = 8
#    col_6 = 2
#    col_7 = 7
#    col_8 = 3
#  *                  10803  0.08s                  5  = col_2
# -------------------------------------------------------------------------------
# Model constraints: 108, variables: integer: 9, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0.08 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 9
#    col_1 = 2
#    col_2 = 5
#    col_3 = 7
#    col_4 = 4
#    col_5 = 1
#    col_6 = 8
#    col_7 = 6
#    col_8 = 3
#  *                  10823  0.08s                  1 != col_5
# -------------------------------------------------------------------------------
# Model constraints: 108, variables: integer: 9, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0.08 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 9
#    col_1 = 6
#    col_2 = 4
#    col_3 = 7
#    col_4 = 1
#    col_5 = 8
#    col_6 = 2
#    col_7 = 5
#    col_8 = 3
#  *                  10863  0.08s                  1  = col_4
# -------------------------------------------------------------------------------
# Model constraints: 108, variables: integer: 9, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0.08 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 9
#    col_1 = 2
#    col_2 = 5
#    col_3 = 7
#    col_4 = 1
#    col_5 = 3
#    col_6 = 8
#    col_7 = 6
#    col_8 = 4
#  *                  10909  0.08s                  6 != col_7
# -------------------------------------------------------------------------------
# Model constraints: 108, variables: integer: 9, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0.08 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 9
#    col_1 = 3
#    col_2 = 6
#    col_3 = 2
#    col_4 = 7
#    col_5 = 5
#    col_6 = 1
#    col_7 = 8
#    col_8 = 4
#  *                  10927  0.08s                  3 != col_7
# -------------------------------------------------------------------------------
# Model constraints: 108, variables: integer: 9, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0.08 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 9
#    col_1 = 5
#    col_2 = 3
#    col_3 = 1
#    col_4 = 7
#    col_5 = 2
#    col_6 = 8
#    col_7 = 6
#    col_8 = 4
#  *                  10969  0.08s                  1  = col_4
# -------------------------------------------------------------------------------
# Model constraints: 108, variables: integer: 9, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0.08 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 9
#    col_1 = 6
#    col_2 = 2
#    col_3 = 7
#    col_4 = 1
#    col_5 = 3
#    col_6 = 5
#    col_7 = 8
#    col_8 = 4
#  *                  10976  0.08s                  1  = col_7
# -------------------------------------------------------------------------------
# Model constraints: 108, variables: integer: 9, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0.08 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 9
#    col_1 = 6
#    col_2 = 3
#    col_3 = 7
#    col_4 = 2
#    col_5 = 8
#    col_6 = 5
#    col_7 = 1
#    col_8 = 4
#                     11000          2        F     3  = col_7
#  *                  11006  0.08s                  1  = col_6
# -------------------------------------------------------------------------------
# Model constraints: 108, variables: integer: 9, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0.08 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 9
#    col_1 = 7
#    col_2 = 3
#    col_3 = 8
#    col_4 = 2
#    col_5 = 5
#    col_6 = 1
#    col_7 = 6
#    col_8 = 4
#  *                  11043  0.08s                  1  = col_6
# -------------------------------------------------------------------------------
# Model constraints: 108, variables: integer: 9, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0.08 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 9
#    col_1 = 4
#    col_2 = 6
#    col_3 = 8
#    col_4 = 2
#    col_5 = 7
#    col_6 = 1
#    col_7 = 3
#    col_8 = 5
#  *                  11073  0.08s                  1  = col_5
# -------------------------------------------------------------------------------
# Model constraints: 108, variables: integer: 9, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0.08 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 9
#    col_1 = 2
#    col_2 = 6
#    col_3 = 8
#    col_4 = 3
#    col_5 = 1
#    col_6 = 4
#    col_7 = 7
#    col_8 = 5
#  *                  11083  0.08s                  1  = col_3
# -------------------------------------------------------------------------------
# Model constraints: 108, variables: integer: 9, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0.08 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 9
#    col_1 = 4
#    col_2 = 8
#    col_3 = 1
#    col_4 = 3
#    col_5 = 6
#    col_6 = 2
#    col_7 = 7
#    col_8 = 5
#  *                  11092  0.08s                  2 != col_6
# -------------------------------------------------------------------------------
# Model constraints: 108, variables: integer: 9, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0.08 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 9
#    col_1 = 4
#    col_2 = 2
#    col_3 = 7
#    col_4 = 3
#    col_5 = 6
#    col_6 = 8
#    col_7 = 1
#    col_8 = 5
#  *                  11176  0.08s                  2 != col_2
# -------------------------------------------------------------------------------
# Model constraints: 108, variables: integer: 9, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0.08 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 9
#    col_1 = 3
#    col_2 = 6
#    col_3 = 2
#    col_4 = 7
#    col_5 = 1
#    col_6 = 4
#    col_7 = 8
#    col_8 = 5
#  *                  11226  0.08s                  3 != col_1
# -------------------------------------------------------------------------------
# Model constraints: 108, variables: integer: 9, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0.08 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 9
#    col_1 = 7
#    col_2 = 4
#    col_3 = 2
#    col_4 = 8
#    col_5 = 6
#    col_6 = 1
#    col_7 = 3
#    col_8 = 5
#  *                  11306  0.08s                  4 != col_4
# -------------------------------------------------------------------------------
# Model constraints: 108, variables: integer: 9, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0.08 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 9
#    col_1 = 3
#    col_2 = 5
#    col_3 = 2
#    col_4 = 8
#    col_5 = 1
#    col_6 = 7
#    col_7 = 4
#    col_8 = 6
#  *                  11325  0.08s                  3  = col_7
# -------------------------------------------------------------------------------
# Model constraints: 108, variables: integer: 9, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0.08 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 9
#    col_1 = 4
#    col_2 = 1
#    col_3 = 5
#    col_4 = 8
#    col_5 = 2
#    col_6 = 7
#    col_7 = 3
#    col_8 = 6
#  *                  11352  0.08s                  1  = col_2
# -------------------------------------------------------------------------------
# Model constraints: 108, variables: integer: 9, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0.08 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 9
#    col_1 = 5
#    col_2 = 1
#    col_3 = 8
#    col_4 = 4
#    col_5 = 2
#    col_6 = 7
#    col_7 = 3
#    col_8 = 6
#  *                  11389  0.08s                  1  = col_4
#  ! Time = 0.08s, Average fail depth = 6, Memory usage = 605.2 kB
#  !               Branches  Non-fixed            Branch decision
# -------------------------------------------------------------------------------
# Model constraints: 108, variables: integer: 9, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0.08 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 9
#    col_1 = 7
#    col_2 = 2
#    col_3 = 4
#    col_4 = 1
#    col_5 = 8
#    col_6 = 5
#    col_7 = 3
#    col_8 = 6
#  *                  11536  0.08s                  1  = col_6
# -------------------------------------------------------------------------------
# Model constraints: 108, variables: integer: 9, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0.08 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 9
#    col_1 = 4
#    col_2 = 2
#    col_3 = 5
#    col_4 = 8
#    col_5 = 6
#    col_6 = 1
#    col_7 = 3
#    col_8 = 7
#  *                  11568  0.08s                  3 != col_7
# -------------------------------------------------------------------------------
# Model constraints: 108, variables: integer: 9, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0.08 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 9
#    col_1 = 5
#    col_2 = 3
#    col_3 = 1
#    col_4 = 6
#    col_5 = 8
#    col_6 = 2
#    col_7 = 4
#    col_8 = 7
#  *                  11574  0.08s                  4  = col_7
# -------------------------------------------------------------------------------
# Model constraints: 108, variables: integer: 9, interval: 0, sequence: 0
# Solve status: Feasible
# Search status: SearchOngoing, stop cause: SearchHasNotBeenStopped
# Solve time: 0.08 sec
# -------------------------------------------------------------------------------
# Variables:
#    col_0 = 9
#    col_1 = 6
#    col_2 = 3
#    col_3 = 1
#    col_4 = 8
#    col_5 = 5
#    col_6 = 2
#    col_7 = 4
#    col_8 = 7
#  ! ----------------------------------------------------------------------------
#  ! Search completed, 352 solutions found.
#  ! ----------------------------------------------------------------------------
#  ! Number of branches     : 11702
#  ! Number of fails        : 5500
#  ! Total memory usage     : 646.0 kB (605.9 kB CP Optimizer + 40.1 kB Concert)
#  ! Time spent in solve    : 0.08s (0.08s engine + 0.00s extraction)
#  ! Search speed (br. / s) : 146275.0
#  ! ----------------------------------------------------------------------------

# %% [markdown]
# ### 1.2. Model with global constraints

# %% [markdown]
# **Exercice:** Create a function `global_constraint_model(N)` that models and returns an instance of `CpoModel` for the n-queens problem with `N` queens, using **only** and exaclty 3 global constraints.

# %%
def global_constraint_model(N):
    
    ##Modele : 
    mdl = CpoModel(name='N_Queens')
    
    ##Variables : 
    x,i,j = mdl.integer_var_list(3, 1, N, 'x')
    
    ##Contraintes
    mdl.add(all_diff(i,j))
    mdl.add(all_diff(x[i],x[j]))
    mdl.add(all_diff((x[i]-x[j]),(x[j]-x[i])))
            
    return mdl

# %% [markdown]
# **Exercice:** Test your function by solving the n-queens problem for small values of $N$ ($N < 20$).

# %%
import display
# %matplotlib inline

for N in range(5,20,1):
    mdl = global_constraint_model(N)
    sol = mdl.solve()
    display.n_queens(sol.get_all_var_solutions())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_18019/1565423077.py in <module>
#       3
#       4 for N in range(5,20,1):
# ----> 5     mdl = global_constraint_model(N)
#       6     sol = mdl.solve()
#       7     display.n_queens(sol.get_all_var_solutions())
#
# /tmp/ipykernel_18019/2017793710.py in global_constraint_model(N)
#       9     ##Contraintes
#      10     mdl.add(all_diff(i,j))
# ---> 11     mdl.add(all_diff(x[i],x[j]))
#      12     mdl.add(all_diff((x[i]-x[j]),(x[j]-x[i])))
#      13
#
# TypeError: 'CpoIntVar' object is not subscriptable

# %% [markdown]
# **Question**: How many solutions are there for $N = 3,~\ldots,~10$?
#
# **Important:** You should obtain the same number as the previous model!

# %% [markdown]
# ## 2. Comparison of the two models

# %% [markdown]
# We will compare the two models properly.
#
# **Exercice:** Consider the `run(model, params)` function that we used in the first tutorial and paste it here.

# %% [markdown]
# ### 2.1. Basic comparison
#
# To compare the two models, we will fix the time limit to 5 seconds, i.e. `TimeLimit=5`, while keeping all the other parameters to their default values.

# %% [markdown]
# **Exercice:** Compare the two models for $N \in \{200, 400, 600, .., 2000 \}$.
#
# <div class="alert alert-block alert-info">
#
# By *comparing* we mean plotting the runtime **and** the number of decisions made by the solver for each model as a function of $n$
#
# </div>

# %% [markdown]
# **Question:** What do you observe? Why?

# %% [markdown]
# ### 2.2. Branching strategies
#
#
# **Important:** Before you start this part, please ask one of your supervisors to check on your work.
#
# A CP solver is, at the end of the day, a backtracking solver. At each node, it applies filtering (called also propagation or pruning), then make a decision about the next node to explore. This decision is a pure heuristic choice, that is, it could be a wrong decision, it is only based on intuition.
#
# In CP, a decision is, most of the times, of the type: choose an unassigned variable $x$, choose a value $v$ from the current domain of $x$, and assign $v$ to $x$. These steps require a variable heuristic and a value heuristic. This is what we call branching strategy.
#
# Branching strategies can be generic (strategies that can be used for any problem), or specific (designed for the problem at hand). In CPOptimizer, there are a number of genereic strategies offered. This concerns both variable and value heuristics.
#
# For example, if $L$ is the list of decision variables, then by declaring a search_phase as follows:
#
# ```python
# SearchPhase= model.search_phase(L,
#                                 varchooser=model.select_smallest(model.domain_size()),
#                                 valuechooser=model.select_random_value())
#
# model.add_search_phase(SearchPhase)
# ```
#
# The variable heuristic here is the one that picks the variable $x$ with the smallest domain size, and assigns a random value from its domain to it.
#
#
# Read about the different search strategies here:
# http://ibmdecisionoptimization.github.io/docplex-doc/cp/docplex.cp.modeler.py.html#search-phases
#
#
# We want to evaluate different strategies:
# - For variable evaluators, we will use
#  - `domain_size()`
#  - `var_impact()`
#  - `var_local_impact()`
#  - `var_index()`
#
# - For value evaluators, we will use
#  - `value_impact()`
#  - `value_index()`
#
# As for the selectors we will use :
# - `select_smallest()`
# - `select_largest()`
#
# **Question:** How many strategies are we going to evaluate?

# %% [markdown]
# **Question:** In addition to the above strategies, we will use also a pure random selection for variables and values. How can we use such a branching heuristic?

# %% [markdown]
# Using the global constraints model, run the different strategies (**all of them, and pure random**) for different values of $N$. Make sure you choose a good value of $N$ that can assess your claims of evaluation. Feel free to use any reasnable time limit.
#
# <div class="alert alert-block alert-danger">
#
# **Important:** For this exercice, you must set the `SearchType` to `DepthFirst` using `SearchType="DepthFirst"` when calling `run`.
#
# We will investigate deeply this choice in the next tutorial. But at this stage you should trust us and include it in the solver's parameters.
#
# </div>
#
# **Exercice:** Present the results (rutime + number of nodes) via a table first then using plots.

# %% [markdown]
# # Plots

# %% [markdown]
# # Compare value chooser

# %% [markdown]
# ## var chooser = select smallest

# %% [markdown]
# ## varchooser = select largest

# %% [markdown]
# # Compare var chooser

# %% [markdown]
# ## Value chooser = smallest value impact

# %% [markdown]
# ## Value chooser = smallest value index

# %% [markdown]
# ## Value chooser = largest value impact

# %% [markdown]
# ## Value chooser = larget value index

# %% [markdown]
# ## Random select

# %% [markdown]
# **Question:** Is this what you expect? Is the choice of the branching strategy important? Justify.

# %% [markdown]
# On attendait plus de variations et moins de timeout : presque toutes les stratégies ont un timeout après n=50

# %% [markdown]
# **Question:** What is more important, the variable ordering or the value ordering choice? Justify.

# %% [markdown]
# Pour un value chooser donné, le choix du var chooser impacte plus les résultats. Alors que sur les plots on remarque que pour un var chooser donné, le value chooser ne change rien aux résultats.

# %% [markdown]
# **Question:** What is the best variable ordering choice? Justify.

# %% [markdown]
# Le meilleur semble être le smallest domain size : il a le moins de timeout, le moins de noeuds, et le plus de solutions feasible (les autres ont trop de unknown)

# %% [markdown]
# **Question:** What is the best value ordering choice? Justify.

# %% [markdown]
# Pas de différences observées

# %% [markdown]
# **Question:** What is a good branching overall? Any thoughts why this is the case? Justify.

# %% [markdown]
# Le random est étonnement plutôt bon dans notre cas

# %% [markdown]
# **Question:** Did you observe an opposite behaviour of heuristics betwen the runtime and the number of nodes?
# For instance, is there a strategy that is faster than others to solve the problem but requires a larger number of nodes?
# And conversely, is there a heuristic that is slow to solve the problem than others but uses less nodes?
# If you observe this, why is this happening?

# %% [markdown]
# ## 3. Conclusion
#
# **Question:** What did you learn today?

# %% [markdown]
# <div class="alert alert-block alert-danger"></div>
